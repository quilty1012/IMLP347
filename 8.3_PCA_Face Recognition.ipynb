# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # Problem : Principal Component Analysis
# **Principal component analysis** (PCA) is a technique of dimensionality reduction, which linearly maps data onto a lower-dimensional space, so that the variance of the projected data in the associated dimensions would be maximized. In this problem, you will perform PCA on a dataset of face images.

# %%
X_train, X_test = [],[]
Y_train, Y_test = [],[]

for i in range(1,41):
    for j in range(1,10):
        img= cv2.imread('data/{}_{}.png'.format(i,j),cv2.IMREAD_GRAYSCALE)
        X_train.append(img)
        Y_train.append(i)
    img = cv2.imread('data/{}_10.png'.format(i),cv2.IMREAD_GRAYSCALE)
    X_test.append(img)
    Y_test.append(i)
    
X_train= np.array(X_train)
X_test= np.array(X_test)
Y_train= np.array(Y_train)
Y_test= np.array(Y_test)
print(X_train.shape, Y_train.shape)
print(X_test.shape,Y_test.shape)
# Out:
# (360, 56, 46) (360,)
# (40, 56, 46) (40,)

# %% [markdown]
# ## 1. mean face & first four eigenfaces

# %%
pca=PCA()
pca.fit(X_train.reshape(len(Y_train),-1))
plt.figure(figsize=(16,12))
plt.subplot(1,5,1)
plt.axis('off')
plt.title("Mean face")
plt.imshow(pca.mean_.reshape(X_train[0].shape),cmap='gray')

print(X_train.reshape(len(Y_train),-1).shape)

for i in range(4):
    plt.subplot(1,5,i+2)
    plt.axis('off')
    plt.title('Eigenface {}'.format(i+1))
    plt.imshow(pca.components_[i].reshape(X_train[0].shape), cmap='gray')
    
plt.show()
# Out:
# (360, 2576)

# %%
image = cv2.imread('data/1_10.png',cv2.IMREAD_GRAYSCALE)


# 將圖片向量轉換為浮點數類型
plt.imshow(image)
image_vector = image.astype(float).reshape(-1)

# 減去平均值
image_vector -= pca.mean_

# 執行 PCA 轉換
transformed_vector = pca.transform([image_vector])

# 使用 pca.components_ 進行重構
reconstructed_vector = pca.inverse_transform(transformed_vector)

# 將重構向量轉換回 'uint8' 數據類型
reconstructed_vector = reconstructed_vector.astype(np.uint8)

# 將重構向量重新恢復為圖片形狀
reconstructed_image = reconstructed_vector.reshape(image.shape)
plt.imshow(reconstructed_image)

# %%
image_vector = image.astype(float).reshape(-1)

# 减去平均脸
image_vector -= pca.mean_

# 提取第一主成分
first_component = pca.components_[0]

# 使用第一主成分进行重构
reconstructed_vector = np.dot(image_vector, first_component) * first_component + pca.mean_

# 将重构后的向量恢复为图像形状
reconstructed_image = reconstructed_vector.reshape(image.shape)
plt.imshow(reconstructed_image)

# %% [markdown]
# ## 2. Reconstruct person2 image1 using the first n = 3, 50, 170, 240, 345 eigenfaces
# ## 3. compute the mean squared error

# %%
img=cv2.imread('data/2_1.png',cv2.IMREAD_GRAYSCALE).reshape(1,-1)
a=pca.transform(img)

plt.figure(figsize=(16,12))
n_components=[1,50,170,240,345]
for i,n in enumerate(n_components):
    face = np.zeros(img.shape)
    for j in range(n):
        face = face + a[0][j]*pca.components_[j]
    face=face+pca.mean_
    MSE=np.mean((face-img)**2)
    plt.subplot(1,5,i+1)
    plt.axis('off')
    plt.title('n={},MSE={:.2f}'.format(n,MSE))
    plt.imshow(face.reshape(X_train[0].shape),cmap='gray')
    
    
print(a.shape)
# Out:
# (1, 360)

# %% [markdown]
# ## 4. cross-validation results

# %%
reduced_X_train = pca.transform(X_train.reshape(len(Y_train),-1))
K=[1,3,5]
N=[3,50,170]
random=np.random.permutation(len(Y_train))
reduced_X_train=reduced_X_train[random]
Y_train_random=Y_train[random]

for k in K:
    print("k={}".format(k))
    knn=KNeighborsClassifier(n_neighbors=k)
    for n in N:
        print('n={}'.format(n),end='')
        score=cross_val_score(knn,reduced_X_train[:,:n],Y_train_random,cv=3)
        print('score={:.4f}'.format(score.mean()))
# Out:
# k=1
# n=3score=0.7111
# n=50score=0.9806
# n=170score=0.9806
# k=3
# n=3score=0.6278
# n=50score=0.9056
# n=170score=0.8972
# k=5
# n=3score=0.5694
# n=50score=0.8806
# n=170score=0.8667

# %% [markdown]
# ## 5. recognition rate of the testing set

# %%
k=1
n=50

reduced_X_test=pca.transform(X_test.reshape(len(Y_test),-1))

knn=KNeighborsClassifier(n_neighbors=k)
knn.fit(reduced_X_train[:,:n],Y_train_random)

print('accuracy={}'.format(knn.score(reduced_X_test[:,:n],Y_test)))
# Out:
# accuracy=0.925

# %%
a=pca.transform(img)
face = np.zeros(img.shape)
face = face + a[0][0]*pca.components_[0]+ pca.mean_
plt.imshow(face.reshape(X_train[0].shape),cmap='gray')

# %%
face = np.zeros(img.shape)
face=np.dot(face , pca.components_[0]) * pca.components_[0]+ pca.mean_
plt.imshow(face.reshape(X_train[0].shape),cmap='gray')
